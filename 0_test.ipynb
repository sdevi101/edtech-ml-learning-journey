# %% [markdown]
# <a href="https://colab.research.google.com/github/sdevi101/edtech-ml-learning-journey/blob/main/0_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day 1: Linear Regression

## 🔍 What I Learned
- Concept of MSE, cost function
- sklearn `LinearRegression` usage
- Underfitting vs overfitting

## 📦 Code

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
